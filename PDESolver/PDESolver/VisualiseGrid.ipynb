# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import numpy as np
from matplotlib import cm
from matplotlib import pyplot as plt
import pandas as pd

# %%
a = pd.read_csv("timing.csv")
a.ExplicitTiming.mean()
a.CNTiming.mean()

# %%
grid = pd.read_csv("ExplicitGrid.csv")

xDim = len(np.unique(grid.xValues))
yDim = len(np.unique(grid.tValues))

fig = plt.figure()
ax = fig.gca(projection='3d')


X = np.reshape(grid.tValues, (xDim,yDim))
ax.set_xlabel(r'$t$')

Y = np.reshape(grid.xValues, (xDim,yDim))
ax.set_ylabel(r'$x$')

Z = np.reshape(grid.Solution, (xDim,yDim))
ax.set_zlabel(r'$u(t,x)$')

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)

plt.savefig("HeatExplicitGrid.png")

plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
grid = pd.read_csv("CNGrid.csv")

xDim = len(np.unique(grid.xValues))
yDim = len(np.unique(grid.tValues))

fig = plt.figure()
ax = fig.gca(projection='3d')

X = np.reshape(grid.tValues, (xDim,yDim))
ax.set_xlabel(r'$t$')

Y = np.reshape(grid.xValues, (xDim,yDim))
ax.set_ylabel(r'$x$')

Z = np.reshape(grid.Solution, (xDim,yDim))
ax.set_zlabel(r'$u(t,x)$')

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)

plt.savefig("HeatCNGrid.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
optimalgrid = pd.read_csv("HeatOptimalExplicit.csv")

xDim = len(np.unique(optimalgrid.xSize))
yDim = len(np.unique(optimalgrid.tSize))

X = np.reshape(optimalgrid.xSize, (xDim,yDim))
Y = np.reshape(optimalgrid.tSize, (xDim,yDim))
Z = np.reshape(optimalgrid.Error, (xDim,yDim))

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)
ax.set_xlabel('x Grid Size')
ax.set_ylabel('t Grid Size')
ax.set_zlabel('Error')
plt.savefig("HeatExplicitGridError.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
optimalgrid = pd.read_csv("HeatOptimalExplicit.csv")

xDim = len(np.unique(optimalgrid.xSize))
yDim = len(np.unique(optimalgrid.tSize))

X = np.reshape(optimalgrid.xSize, (xDim,yDim))
Y = np.reshape(optimalgrid.tSize, (xDim,yDim))
Z = np.reshape(optimalgrid.Time, (xDim,yDim))

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(Y, X, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)
ax.set_ylabel('x Grid Size')
ax.set_xlabel('t Grid Size')
ax.set_zlabel('Time')
plt.savefig("HeatExplicitGridTimer.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
optimalgrid = pd.read_csv("HeatOptimalCN.csv")

xDim = len(np.unique(optimalgrid.xSize))
yDim = len(np.unique(optimalgrid.tSize))

X = np.reshape(optimalgrid.xSize, (xDim,yDim))
Y = np.reshape(optimalgrid.tSize, (xDim,yDim))
Z = np.reshape(optimalgrid.Error, (xDim,yDim))

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)
ax.set_ylabel('x Grid Size')
ax.set_xlabel('t Grid Size')
ax.set_zlabel('Error')
plt.savefig("CNGridError.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
optimalgrid = pd.read_csv("HeatOptimalCN.csv")

xDim = len(np.unique(optimalgrid.xSize))
yDim = len(np.unique(optimalgrid.tSize))

X = np.reshape(optimalgrid.xSize, (xDim,yDim))
Y = np.reshape(optimalgrid.tSize, (xDim,yDim))
Z = np.reshape(optimalgrid.Time, (xDim,yDim))

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(Y, X, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)
ax.set_ylabel('x Grid Size')
ax.set_xlabel('t Grid Size')
ax.set_zlabel('Time')
plt.savefig("CNGridTimer.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
grid = pd.read_csv("ExplicitGrid.csv")

xDim = len(np.unique(grid.xValues))
yDim = len(np.unique(grid.tValues))

fig = plt.figure()
ax = fig.gca(projection='3d')

X = np.reshape(grid.tValues, (xDim,yDim))
ax.set_xlabel(r'$T-t$')

Y = np.reshape(grid.xValues, (xDim,yDim))
ax.set_ylabel(r'$S$')

Z = np.reshape(grid.Solution, (xDim,yDim))
ax.set_zlabel(r'$C(S,t)$')

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)

plt.savefig("BSExplicitGrid.png")

plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
grid = pd.read_csv("CNGrid.csv")

xDim = len(np.unique(grid.xValues))
yDim = len(np.unique(grid.tValues))

fig = plt.figure()
ax = fig.gca(projection='3d')

X = np.reshape(grid.tValues, (xDim,yDim))
ax.set_xlabel(r'$T-t$')

Y = np.reshape(grid.xValues, (xDim,yDim))
ax.set_ylabel(r'$S$')

Z = np.reshape(grid.Solution, (xDim,yDim))
ax.set_zlabel(r'$C(S,t)$')

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)

plt.savefig("BSCNGrid.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
optimalgrid = pd.read_csv("BSOptimalExplicit.csv")

xDim = len(np.unique(optimalgrid.xSize))
yDim = len(np.unique(optimalgrid.tSize))

X = np.reshape(optimalgrid.xSize, (xDim,yDim))
Y = np.reshape(optimalgrid.tSize, (xDim,yDim))
Z = np.reshape(optimalgrid.Error, (xDim,yDim))

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)
ax.set_xlabel('x Grid Size')
ax.set_ylabel('t Grid Size')
ax.set_zlabel('Error')
plt.savefig("BSExplicitGridError.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
optimalgrid = pd.read_csv("BSOptimalExplicit.csv")

xDim = len(np.unique(optimalgrid.xSize))
yDim = len(np.unique(optimalgrid.tSize))

X = np.reshape(optimalgrid.xSize, (xDim,yDim))
Y = np.reshape(optimalgrid.tSize, (xDim,yDim))
Z = np.reshape(optimalgrid.Time, (xDim,yDim))

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(Y, X, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)
ax.set_ylabel('x Grid Size')
ax.set_xlabel('t Grid Size')
ax.set_zlabel('Time')
plt.savefig("BSExplicitGridTimer.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
optimalgrid = pd.read_csv("BSOptimalCN.csv")

xDim = len(np.unique(optimalgrid.xSize))
yDim = len(np.unique(optimalgrid.tSize))

X = np.reshape(optimalgrid.xSize, (xDim,yDim))
Y = np.reshape(optimalgrid.tSize, (xDim,yDim))
Z = np.reshape(optimalgrid.Error, (xDim,yDim))

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)
ax.set_ylabel('x Grid Size')
ax.set_xlabel('t Grid Size')
ax.set_zlabel('Error')
plt.savefig("CNGridError.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
optimalgrid = pd.read_csv("BSOptimalCN.csv")

xDim = len(np.unique(optimalgrid.xSize))
yDim = len(np.unique(optimalgrid.tSize))

X = np.reshape(optimalgrid.xSize, (xDim,yDim))
Y = np.reshape(optimalgrid.tSize, (xDim,yDim))
Z = np.reshape(optimalgrid.Time, (xDim,yDim))

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(Y, X, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)
ax.set_ylabel('x Grid Size')
ax.set_xlabel('t Grid Size')
ax.set_zlabel('Time')
plt.savefig("CNGridTimer.png")
plt.show()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
timing = pd.read_csv("BSTiming.csv")
print(str(round(timing.Explicit.mean(),8)) + " & " + str(round(timing.CN.mean(),8)))
# Out:
# 0.04141765 & 0.03951554

# %%
timing = pd.read_csv("HeatTiming.csv")
print(str(round(timing.Explicit.mean(),8)) + " & " + str(round(timing.CN.mean(),8)) + " & " + str(round(timing.ADI.mean(),8)))
# Out:
# 0.02239165 & 0.02195975 & 0.06337759

# %%
optimalgrid = pd.read_csv("ADIGrid.csv")

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = grid.xValues
y = grid.yValues
c = grid.Solution
z = grid.tValues

img = ax.scatter(x, y, z, c=c, cmap=plt.hot())
fig.colorbar(img)
plt.savefig("ADIHeat.png")
plt.show()
